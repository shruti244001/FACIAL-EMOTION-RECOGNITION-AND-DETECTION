# %%
pip install fer
# Out:
# Requirement already satisfied: fer in c:\programdata\anaconda3\lib\site-packages (22.4.0)
# Requirement already satisfied: mtcnn>=0.1.1 in c:\programdata\anaconda3\lib\site-packages (from fer) (0.1.1)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from fer) (3.4.3)
# Requirement already satisfied: opencv-contrib-python in c:\programdata\anaconda3\lib\site-packages (from fer) (4.6.0.66)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from fer) (2.26.0)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from fer) (4.62.3)
# Requirement already satisfied: keras>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from fer) (2.8.0)
# Requirement already satisfied: opencv-python>=4.1.0 in c:\programdata\anaconda3\lib\site-packages (from mtcnn>=0.1.1->fer) (4.5.5.64)
# Requirement already satisfied: numpy>=1.14.5 in c:\programdata\anaconda3\lib\site-packages (from opencv-python>=4.1.0->mtcnn>=0.1.1->fer) (1.20.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->fer) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->fer) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->fer) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->fer) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->fer) (0.10.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->fer) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->fer) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->fer) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->fer) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->fer) (3.2)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm->fer) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -lrd (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lrd (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lrd (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lrd (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lrd (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lrd (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)

# %%
import cv2
 
from fer import FER
 
import matplotlib.pyplot as plt
 
import matplotlib.image as mpimg

# %%
# Input Image
input_image = cv2.imread("C://Users//H.P//Pictures//Saved Pictures//Online.jpg")
emotion_detector = FER()
# Output image's information
print(emotion_detector.detect_emotions(input_image))
# Out:
# [{'box': array([217,  65, 120, 120]), 'emotions': {'angry': 0.0, 'disgust': 0.0, 'fear': 0.0, 'happy': 1.0, 'sad': 0.0, 'surprise': 0.0, 'neutral': 0.0}}]

# %%
[{'box': [277, 90, 48, 63], 'emotions': {
  'angry': 0.02, 'disgust': 0.0, 'fear': 0.05,
  'happy': 0.16, 'neutral': 0.09, 'sad': 0.27, 'surprise': 0.41}}]
# Out:
# [{'box': [277, 90, 48, 63],
#   'emotions': {'angry': 0.02,
#    'disgust': 0.0,
#    'fear': 0.05,
#    'happy': 0.16,
#    'neutral': 0.09,
#    'sad': 0.27,
#    'surprise': 0.41}}]

# %%
result = emotion_detector.detect_emotions(input_image)

# %%
result
# Out:
# [{'box': array([217,  65, 120, 120]),
#   'emotions': {'angry': 0.0,
#    'disgust': 0.0,
#    'fear': 0.0,
#    'happy': 1.0,
#    'sad': 0.0,
#    'surprise': 0.0,
#    'neutral': 0.0}}]

# %%
bounding_box = result[0]["box"]
emotions = result[0]["emotions"]
cv2.rectangle(input_image,(
  bounding_box[0], bounding_box[1]),(
  bounding_box[0] + bounding_box[2], bounding_box[1] + bounding_box[3]),
              (0, 155, 255), 2,)
# Out:
# array([[[247, 252, 251],
#         [247, 252, 251],
#         [247, 252, 251],
#         ...,
#         [217, 223, 230],
#         [220, 226, 233],
#         [222, 228, 233]],
#
#        [[247, 252, 251],
#         [247, 252, 251],
#         [247, 252, 251],
#         ...,
#         [215, 221, 228],
#         [217, 223, 230],
#         [219, 225, 230]],
#
#        [[247, 252, 251],
#         [247, 252, 251],
#         [247, 252, 251],
#         ...,
#         [213, 219, 226],
#         [215, 221, 228],
#         [217, 223, 230]],
#
#        ...,
#
#        [[ 13,  21,  34],
#         [ 14,  23,  33],
#         [ 17,  23,  34],
#         ...,
#         [  2,  37,  47],
#         [  2,  35,  44],
#         [  2,  33,  42]],
#
#        [[ 17,  23,  34],
#         [ 18,  24,  35],
#         [ 21,  25,  36],
#         ...,
#         [  4,  32,  43],
#         [  4,  31,  41],
#         [  2,  29,  39]],
#
#        [[ 19,  25,  36],
#         [ 20,  26,  37],
#         [ 22,  26,  37],
#         ...,
#         [  0,  26,  38],
#         [  1,  26,  36],
#         [  1,  23,  34]]], dtype=uint8)

# %%
emotion_name, score = emotion_detector.top_emotion(input_image)
for index, (emotion_name, score) in enumerate(emotions.items()):
   color = (211, 211,211) if score < 0.01 else (255, 0, 0)
   emotion_score = "{}: {}".format(emotion_name, "{:.2f}".format(score))
 
   cv2.putText(input_image,emotion_score,
               (bounding_box[0], bounding_box[1] + bounding_box[3] + 30 + index * 15),
               cv2.FONT_HERSHEY_SIMPLEX,0.5,color,1,cv2.LINE_AA,)
 
#Save the result in new image file
cv2.imwrite("emotion.jpg", input_image)
# Out:
# True

# %%
import cv2
from fer import FER
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
input_image = cv2.imread("C://Users//H.P//Pictures//Saved Pictures//Online.jpg")
emotion_detector = FER(mtcnn=True)

# %%
result = emotion_detector.detect_emotions(input_image)

# %%
bounding_box = result[0]["box"]
emotions = result[0]["emotions"]
cv2.rectangle(input_image,(
  bounding_box[0], bounding_box[1]),(
  bounding_box[0] + bounding_box[2], bounding_box[1] + bounding_box[3]),
              (0, 155, 255), 2,)
# Out:
# array([[[247, 252, 251],
#         [247, 252, 251],
#         [247, 252, 251],
#         ...,
#         [217, 223, 230],
#         [220, 226, 233],
#         [222, 228, 233]],
#
#        [[247, 252, 251],
#         [247, 252, 251],
#         [247, 252, 251],
#         ...,
#         [215, 221, 228],
#         [217, 223, 230],
#         [219, 225, 230]],
#
#        [[247, 252, 251],
#         [247, 252, 251],
#         [247, 252, 251],
#         ...,
#         [213, 219, 226],
#         [215, 221, 228],
#         [217, 223, 230]],
#
#        ...,
#
#        [[ 13,  21,  34],
#         [ 14,  23,  33],
#         [ 17,  23,  34],
#         ...,
#         [  2,  37,  47],
#         [  2,  35,  44],
#         [  2,  33,  42]],
#
#        [[ 17,  23,  34],
#         [ 18,  24,  35],
#         [ 21,  25,  36],
#         ...,
#         [  4,  32,  43],
#         [  4,  31,  41],
#         [  2,  29,  39]],
#
#        [[ 19,  25,  36],
#         [ 20,  26,  37],
#         [ 22,  26,  37],
#         ...,
#         [  0,  26,  38],
#         [  1,  26,  36],
#         [  1,  23,  34]]], dtype=uint8)

# %%
emotion_name, score = emotion_detector.top_emotion(input_image)
for index, (emotion_name, score) in enumerate(emotions.items()):
   color = (211, 211,211) if score < 0.01 else (255, 0, 0)
   emotion_score = "{}: {}".format(emotion_name, "{:.2f}".format(score))
 
   cv2.putText(input_image,emotion_score,
               (bounding_box[0], bounding_box[1] + bounding_box[3] + 30 + index * 15),
               cv2.FONT_HERSHEY_SIMPLEX,0.5,color,1,cv2.LINE_AA,)
 
#Save the result in new image file
cv2.imwrite("emotion.jpg", input_image)
# Out:
# True

# %%
result_image = mpimg.imread('emotion.jpg')
imgplot = plt.imshow(result_image)
# Display Output Image
plt.show()
